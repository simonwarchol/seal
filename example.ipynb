# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: ANYWIDGET_HMR=1

# %%
# Out:
#    CellID         DNA_6        ELANE        CD57        CD45         DNA_7  \
# 0       1  17597.443478  1176.791304  160.782609  703.991304   5866.643478
# 1       2  18031.086957  1125.282609  176.934783  792.826087  11817.923913
# 2       3   8402.596774  1249.532258  156.951613  816.225806   5040.790323
# 3       4  22322.404412  1156.683824  187.330882  853.250000  13716.878676
# 4       5   8101.017199  1570.628993  163.009828  318.027027   4959.896806
#
#          CD11B          SMA        CD16         DNA_8  ...  Eccentricity  \
# 0   377.400000   245.260870  331.278261   6816.017391  ...      0.295521
# 1   910.304348   422.347826  646.923913  13424.717391  ...      0.541562
# 2  1046.177419   487.854839  601.790323   5557.935484  ...      0.496871
# 3   816.955882  2187.911765  376.194853  15479.356618  ...      0.805900
# 4   826.963145   361.771499  366.088452   5628.589681  ...      0.678529
#
#    Solidity    Extent  Orientation       UMAP_X       UMAP_Y     kmeans  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(df['UMAP_X'], df['UMAP_Y'], alpha=0.1)

# %%
color_map = df['agcluster'].map(lambda x: int(x.split(' ')[1]))
plt.scatter(df['UMAP_X'], df['UMAP_Y'], c=color_map, alpha=0.1)

# %%
# scale between white and color
# plt.scatter(df['UMAP_X'], df['UMAP_Y'], c=df['CD16'], alpha=0.1, cmap='Purples')
# Make 4 subplots as all columns of the same row, for c=CD16, CD57	CD45, FOXP3
fig, axs = plt.subplots(1, 4, figsize=(20, 5))
axs[0].scatter(df['UMAP_X'], df['UMAP_Y'], c=df['CD16'], alpha=0.1, cmap='Purples')
axs[1].scatter(df['UMAP_X'], df['UMAP_Y'], c=df['CD57'], alpha=0.1, cmap='Purples')
axs[2].scatter(df['UMAP_X'], df['UMAP_Y'], c=df['CD45'], alpha=0.1, cmap='Purples')
axs[3].scatter(df['UMAP_X'], df['UMAP_Y'], c=df['FOXP3'], alpha=0.1, cmap='Purples')
# Add titles
axs[0].set_title('CD16')
axs[1].set_title('CD57')
axs[2].set_title('CD45')
axs[3].set_title('FOXP3')
# Out:
# Text(0.5, 1.0, 'FOXP3')

# %%
df.columns
# Out:
# Index(['CellID', 'DNA_6', 'ELANE', 'CD57', 'CD45', 'DNA_7', 'CD11B', 'SMA',
#        'CD16', 'DNA_8', 'ECAD', 'FOXP3', 'NCAM', 'X_centroid', 'Y_centroid',
#        'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity',
#        'Solidity', 'Extent', 'Orientation', 'UMAP_X', 'UMAP_Y', 'kmeans',
#        'agcluster', 'EEMB_x', 'EEMB_y'],
#       dtype='object')

# %%
import pandas as pd
df = pd.read_csv('/Users/swarchol/Research/exemplar-001/new/updated.csv')

df.head()

# %%
cluster_columns = ['agcluster','kmeans']
# cluster_columns = ['agcluster']
config = {
    "embeddingImageUrl": "http://localhost:8181/files/embedding_image.ome.tif",
    "embeddingSegmentationUrl": "http://localhost:8181/files/embedding_segmentation.ome.tif",
    "csvUrl": "http://localhost:8181/files/csv.csv",
    "clusterColumns": cluster_columns,
    "imageUrl": "http://localhost:8181/files/image.ome.tif",
    "segmentationUrl": "http://localhost:8181/files/segmentation.ome.tif"
}

# %%
from seal import Seal
Seal(df=df, config=config)
# Out:
# Seal(config={'embeddingImageUrl': 'http://localhost:8181/files/embedding_image.ome.tif', 'embeddingSegmentatio…
# INFO:     Started server process [10809]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 48] error while attempting to bind on address ('127.0.0.1', 8181): address already in use
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
