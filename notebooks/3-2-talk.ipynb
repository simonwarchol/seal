# %%
from sklearn.datasets import load_wine
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import shap
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import shap
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
import xgboost as xgb
from scipy.spatial import ConvexHull, Delaunay
import pickle
import os
import time
# import torch
# import torch.nn as nn
from tqdm.auto import tqdm
import numpy as np

# %%
# csv_df = pd.read_csv('https://vae-bed.s3.us-east-2.amazonaws.com/updated_renamed.csv')
csv_df = pd.read_csv('/Users/swarchol/Research/seal/data/updated_renamed.csv')

# %%
csv_df.columns
# Out:
# Index(['CellID', 'DNA', 'DNA (2)', 'DNA (3)', 'CD3', 'CD45RO', 'DNA (4)',
#        'Pan-cytokeratin', 'Aortic smooth muscle actin', 'DNA (5)', 'CD4',
#        'CD45', 'PD-1', 'DNA (6)', 'CD20', 'CD68', 'CD8a', 'DNA (7)', 'CD163',
#        'FOXP3', 'PD-L1', 'DNA (8)', 'E-cadherin', 'Vimentin', 'CDX-2',
#        'DNA (9)', 'Lamin-A/B/C', 'Desmin', 'CD31', 'DNA (10)', 'PCNA',
#        'Collagen', 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength',
#        'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation',
#        'Sample', 'Condition', 'Replicate', 'emb1', 'emb2', 'cluster_2d',
#        'UMAP_X', 'UMAP_Y', 'kmeans'],
#       dtype='object')

# %%
columns = csv_df.columns
feature_columns = ['DNA', 'DNA (2)', 'DNA (3)', 'CD3', 'CD45RO', 'DNA (4)',
       'Pan-cytokeratin', 'Aortic smooth muscle actin', 'DNA (5)', 'CD4',
       'CD45', 'PD-1', 'DNA (6)', 'CD20', 'CD68', 'CD8a', 'DNA (7)', 'CD163',
       'FOXP3', 'PD-L1', 'DNA (8)', 'E-cadherin', 'Vimentin', 'CDX-2',
       'DNA (9)', 'Lamin-A/B/C', 'Desmin', 'CD31', 'DNA (10)', 'PCNA',
       'Collagen',]

# %%
plt.scatter(csv_df['UMAP_X'], csv_df['UMAP_Y'])

# %%
# regressor = xgb.XGBRegressor()
regressor = xgb.XGBRegressor(
                 n_estimators=2000,
                 max_depth=9,
                 seed=1000)
# !wget https://vae-bed.s3.us-east-2.amazonaws.com/xgb_regressor.json -O xgb_regressor.json
regressor.load_model('xgb_regressor.json')

# %%
xgb_preds = regressor.predict(csv_df[feature_columns])
plt.scatter(xgb_preds[:,0], xgb_preds[:,1], alpha=0.1)

# %%
# regressor.fit(csv_df[feature_columns], csv_df[['UMAP_X','UMAP_Y']])
# Save Regressor
# with open('xgb_regressor.pkl', 'wb') as f:
#     pickle.dump(regressor, f)

# %%
# with open('xgb_regressor.pkl', 'rb') as f:
#     regressor = pickle.load(f)

# %%
# regressor.save_model('xgb_regressor.json')
explainer = shap.Explainer(regressor)

# %%
chunks = np.array_split(csv_df[feature_columns], 1000)

shap_values_list = []
# shap_values_array = None
shap_values_array = np.load('shap_values_array.npy')

# %%
for chunk in tqdm(chunks, desc="Calculating SHAP values"):
    if (chunk.index.stop) <= shap_values_array.shape[0]:
        print(f"Skipping chunk {chunk.index.stop -1} because it is already in shap_values_array")
    else:
        shap_values = explainer(chunk)
        # if shap_values_array is None:
        #     shap_values_array = shap_values.values
        # else:
        shap_values_array = np.concatenate((shap_values_array, shap_values.values), axis=0)
        np.save('shap_values_array.npy', shap_values_array)
# Out:
# Calculating SHAP values:   0%|          | 0/1000 [00:00<?, ?it/s]
# Skipping chunk 933 because it is already in shap_values_array
# Skipping chunk 1867 because it is already in shap_values_array
# Skipping chunk 2801 because it is already in shap_values_array
# Skipping chunk 3735 because it is already in shap_values_array
# Skipping chunk 4669 because it is already in shap_values_array
# Skipping chunk 5603 because it is already in shap_values_array
# Skipping chunk 6537 because it is already in shap_values_array
# Skipping chunk 7471 because it is already in shap_values_array
# Skipping chunk 8405 because it is already in shap_values_array
# Skipping chunk 9339 because it is already in shap_values_array
# Skipping chunk 10273 because it is already in shap_values_array
# Skipping chunk 11207 because it is already in shap_values_array
# Skipping chunk 12141 because it is already in shap_values_array
# Skipping chunk 13075 because it is already in shap_values_array
# Skipping chunk 14009 because it is already in shap_values_array
# Skipping chunk 14943 because it is already in shap_values_array
# Skipping chunk 15877 because it is already in shap_values_array
# Skipping chunk 16811 because it is already in shap_values_array
# Skipping chunk 17745 because it is already in shap_values_array
# Skipping chunk 18679 because it is already in shap_values_array
# Skipping chunk 19613 because it is already in shap_values_array
# Skipping chunk 20547 because it is already in shap_values_array
# Skipping chunk 21481 because it is already in shap_values_array
# Skipping chunk 22415 because it is already in shap_values_array
# Skipping chunk 23349 because it is already in shap_values_array
# Skipping chunk 24283 because it is already in shap_values_array
# Skipping chunk 25217 because it is already in shap_values_array
# Skipping chunk 26151 because it is already in shap_values_array
# Skipping chunk 27085 because it is already in shap_values_array
# Skipping chunk 28019 because it is already in shap_values_array
# Skipping chunk 28953 because it is already in shap_values_array
# Skipping chunk 29887 because it is already in shap_values_array
# Skipping chunk 30821 because it is already in shap_values_array
# Skipping chunk 31755 because it is already in shap_values_array
# Skipping chunk 32689 because it is already in shap_values_array
# Skipping chunk 33623 because it is already in shap_values_array
# Skipping chunk 34557 because it is already in shap_values_array
# Skipping chunk 35491 because it is already in shap_values_array
# Skipping chunk 36425 because it is already in shap_values_array
# Skipping chunk 37359 because it is already in shap_values_array
# Skipping chunk 38293 because it is already in shap_values_array
# Skipping chunk 39227 because it is already in shap_values_array
# Skipping chunk 40161 because it is already in shap_values_array
# Skipping chunk 41095 because it is already in shap_values_array
# Skipping chunk 42029 because it is already in shap_values_array
# Skipping chunk 42963 because it is already in shap_values_array
# Skipping chunk 43897 because it is already in shap_values_array
# Skipping chunk 44831 because it is already in shap_values_array
# Skipping chunk 45765 because it is already in shap_values_array
# Skipping chunk 46699 because it is already in shap_values_array
# Skipping chunk 47633 because it is already in shap_values_array
# Skipping chunk 48567 because it is already in shap_values_array
# Skipping chunk 49501 because it is already in shap_values_array
# Skipping chunk 50435 because it is already in shap_values_array
# Skipping chunk 51369 because it is already in shap_values_array
# Skipping chunk 52303 because it is already in shap_values_array
# Skipping chunk 53237 because it is already in shap_values_array
# Skipping chunk 54171 because it is already in shap_values_array
# Skipping chunk 55105 because it is already in shap_values_array
# Skipping chunk 56039 because it is already in shap_values_array
# Skipping chunk 56973 because it is already in shap_values_array
# Skipping chunk 57907 because it is already in shap_values_array
# Skipping chunk 58841 because it is already in shap_values_array
# Skipping chunk 59775 because it is already in shap_values_array
# Skipping chunk 60709 because it is already in shap_values_array
# Skipping chunk 61643 because it is already in shap_values_array
# Skipping chunk 62577 because it is already in shap_values_array
# Skipping chunk 63511 because it is already in shap_values_array
# Skipping chunk 64445 because it is already in shap_values_array
# Skipping chunk 65379 because it is already in shap_values_array
# Skipping chunk 66313 because it is already in shap_values_array
# Skipping chunk 67247 because it is already in shap_values_array
# Skipping chunk 68181 because it is already in shap_values_array
# Skipping chunk 69115 because it is already in shap_values_array
# Skipping chunk 70049 because it is already in shap_values_array
# Skipping chunk 70983 because it is already in shap_values_array
# Skipping chunk 71917 because it is already in shap_values_array
# Skipping chunk 72851 because it is already in shap_values_array
# Skipping chunk 73785 because it is already in shap_values_array
# Skipping chunk 74719 because it is already in shap_values_array
# Skipping chunk 75653 because it is already in shap_values_array
# Skipping chunk 76587 because it is already in shap_values_array
# Skipping chunk 77521 because it is already in shap_values_array
# Skipping chunk 78455 because it is already in shap_values_array
# Skipping chunk 79389 because it is already in shap_values_array
# Skipping chunk 80323 because it is already in shap_values_array
# Skipping chunk 81257 because it is already in shap_values_array
# Skipping chunk 82191 because it is already in shap_values_array
# Skipping chunk 83125 because it is already in shap_values_array
# Skipping chunk 84059 because it is already in shap_values_array
# Skipping chunk 84993 because it is already in shap_values_array
# Skipping chunk 85927 because it is already in shap_values_array
# Skipping chunk 86861 because it is already in shap_values_array
# Skipping chunk 87795 because it is already in shap_values_array
# Skipping chunk 88729 because it is already in shap_values_array
# Skipping chunk 89663 because it is already in shap_values_array
# Skipping chunk 90597 because it is already in shap_values_array
# Skipping chunk 91531 because it is already in shap_values_array
# Skipping chunk 92465 because it is already in shap_values_array
# Skipping chunk 93399 because it is already in shap_values_array
# Skipping chunk 94333 because it is already in shap_values_array
# Skipping chunk 95267 because it is already in shap_values_array
# Skipping chunk 96201 because it is already in shap_values_array
# Skipping chunk 97135 because it is already in shap_values_array
# Skipping chunk 98069 because it is already in shap_values_array
# Skipping chunk 99003 because it is already in shap_values_array
# Skipping chunk 99937 because it is already in shap_values_array
# Skipping chunk 100871 because it is already in shap_values_array
# Skipping chunk 101805 because it is already in shap_values_array
# Skipping chunk 102739 because it is already in shap_values_array
# Skipping chunk 103673 because it is already in shap_values_array
# Skipping chunk 104607 because it is already in shap_values_array
# Skipping chunk 105541 because it is already in shap_values_array
# Skipping chunk 106475 because it is already in shap_values_array
# Skipping chunk 107409 because it is already in shap_values_array
# Skipping chunk 108343 because it is already in shap_values_array
# Skipping chunk 109277 because it is already in shap_values_array
# Skipping chunk 110211 because it is already in shap_values_array
# Skipping chunk 111145 because it is already in shap_values_array
# Skipping chunk 112079 because it is already in shap_values_array
# Skipping chunk 113013 because it is already in shap_values_array
# Skipping chunk 113947 because it is already in shap_values_array
# Skipping chunk 114881 because it is already in shap_values_array
# Skipping chunk 115815 because it is already in shap_values_array
# Skipping chunk 116749 because it is already in shap_values_array
# Skipping chunk 117683 because it is already in shap_values_array
# Skipping chunk 118617 because it is already in shap_values_array
# Skipping chunk 119551 because it is already in shap_values_array
# Skipping chunk 120485 because it is already in shap_values_array
# Skipping chunk 121419 because it is already in shap_values_array
# Skipping chunk 122353 because it is already in shap_values_array
# Skipping chunk 123287 because it is already in shap_values_array
# Skipping chunk 124221 because it is already in shap_values_array
# Skipping chunk 125155 because it is already in shap_values_array
# Skipping chunk 126089 because it is already in shap_values_array
# Skipping chunk 127023 because it is already in shap_values_array
# Skipping chunk 127957 because it is already in shap_values_array
# Skipping chunk 128891 because it is already in shap_values_array
# Skipping chunk 129825 because it is already in shap_values_array
# Skipping chunk 130759 because it is already in shap_values_array
# Skipping chunk 131693 because it is already in shap_values_array
# Skipping chunk 132627 because it is already in shap_values_array
# Skipping chunk 133561 because it is already in shap_values_array
# Skipping chunk 134495 because it is already in shap_values_array
# Skipping chunk 135429 because it is already in shap_values_array
# Skipping chunk 136363 because it is already in shap_values_array
# Skipping chunk 137297 because it is already in shap_values_array
# Skipping chunk 138231 because it is already in shap_values_array
# Skipping chunk 139165 because it is already in shap_values_array
# Skipping chunk 140099 because it is already in shap_values_array
# Skipping chunk 141033 because it is already in shap_values_array
# Skipping chunk 141967 because it is already in shap_values_array
# Skipping chunk 142901 because it is already in shap_values_array
# Skipping chunk 143835 because it is already in shap_values_array
# Skipping chunk 144769 because it is already in shap_values_array
# Skipping chunk 145703 because it is already in shap_values_array
# Skipping chunk 146637 because it is already in shap_values_array
# Skipping chunk 147571 because it is already in shap_values_array
# Skipping chunk 148505 because it is already in shap_values_array
# Skipping chunk 149439 because it is already in shap_values_array
# Skipping chunk 150373 because it is already in shap_values_array
# Skipping chunk 151307 because it is already in shap_values_array
# Skipping chunk 152241 because it is already in shap_values_array
# Skipping chunk 153175 because it is already in shap_values_array
# Skipping chunk 154109 because it is already in shap_values_array
# Skipping chunk 155043 because it is already in shap_values_array
# Skipping chunk 155977 because it is already in shap_values_array
# Skipping chunk 156911 because it is already in shap_values_array
# Skipping chunk 157845 because it is already in shap_values_array
# Skipping chunk 158779 because it is already in shap_values_array
# Skipping chunk 159713 because it is already in shap_values_array
# Skipping chunk 160647 because it is already in shap_values_array
# Skipping chunk 161581 because it is already in shap_values_array
# Skipping chunk 162515 because it is already in shap_values_array
# Skipping chunk 163449 because it is already in shap_values_array
# Skipping chunk 164383 because it is already in shap_values_array
# Skipping chunk 165317 because it is already in shap_values_array
# Skipping chunk 166251 because it is already in shap_values_array
# Skipping chunk 167185 because it is already in shap_values_array
# Skipping chunk 168119 because it is already in shap_values_array
# Skipping chunk 169053 because it is already in shap_values_array
# Skipping chunk 169987 because it is already in shap_values_array
# Skipping chunk 170921 because it is already in shap_values_array
# Skipping chunk 171855 because it is already in shap_values_array
# Skipping chunk 172789 because it is already in shap_values_array
# Skipping chunk 173723 because it is already in shap_values_array
# Skipping chunk 174657 because it is already in shap_values_array
# Skipping chunk 175591 because it is already in shap_values_array
# Skipping chunk 176525 because it is already in shap_values_array
# Skipping chunk 177459 because it is already in shap_values_array
# Skipping chunk 178393 because it is already in shap_values_array
# Skipping chunk 179327 because it is already in shap_values_array
# Skipping chunk 180261 because it is already in shap_values_array
# Skipping chunk 181195 because it is already in shap_values_array
# Skipping chunk 182129 because it is already in shap_values_array
# Skipping chunk 183063 because it is already in shap_values_array
# Skipping chunk 183997 because it is already in shap_values_array
# Skipping chunk 184931 because it is already in shap_values_array
# Skipping chunk 185865 because it is already in shap_values_array
# Skipping chunk 186799 because it is already in shap_values_array
# Skipping chunk 187733 because it is already in shap_values_array
# Skipping chunk 188667 because it is already in shap_values_array

# %%
(chunk.index.stop) <= shap_values_array.shape[0]
        # print(f"Skipping chunk {chunk.index.stop -1} because it is already in shap_values_array")
        # continue
# Out:
# True

# %%
shap_values_array = np.abs(shap_values_array)

# %%
summed_shap_values = shap_values_array.sum(axis=2)

# %%
cluster = csv_df[csv_df.kmeans == 7]
plt.scatter(csv_df['UMAP_X'], csv_df['UMAP_Y'])
plt.scatter(cluster['UMAP_X'], cluster['UMAP_Y'])

# %%
feature_columns = ['DNA', 'DNA (2)', 'DNA (3)', 'CD3', 'CD45RO', 'DNA (4)',
       'Pan-cytokeratin', 'Aortic smooth muscle actin', 'DNA (5)', 'CD4',
       'CD45', 'PD-1', 'DNA (6)', 'CD20', 'CD68', 'CD8a', 'DNA (7)', 'CD163',
       'FOXP3', 'PD-L1', 'DNA (8)', 'E-cadherin', 'Vimentin', 'CDX-2',
       'DNA (9)', 'Lamin-A/B/C', 'Desmin', 'CD31', 'DNA (10)', 'PCNA',
       'Collagen']
cluster_7 = csv_df[csv_df['kmeans'] == 7].index.tolist()
cluster_7_vals = summed_shap_values[cluster_7]
mean_cluster_7_vals = cluster_7_vals.mean(axis=0)
# bar plot of mean_cluster_7_vals, which have labels as feature_columns
plt.bar(feature_columns, mean_cluster_7_vals)
plt.xticks(rotation=90)
plt.show()

# %%
len(feature_columns)
# Out:
# 31

# %%
mean_summed_shap_values[cluster_7].shape
# Out:
# (78091,)

# %%
old_feat_imp = np.load(f"/Users/swarchol/Research/seal/data/greg.shap.npy")
old_feat_imp.shape
# Out:
# (933253, 21, 2)

# %%
shap_values_array.shape
feature_columns = ['DNA', 'DNA (2)', 'DNA (3)', 'CD3', 'CD45RO', 'DNA (4)',
       'Pan-cytokeratin', 'Aortic smooth muscle actin', 'DNA (5)', 'CD4',
       'CD45', 'PD-1', 'DNA (6)', 'CD20', 'CD68', 'CD8a', 'DNA (7)', 'CD163',
       'FOXP3', 'PD-L1', 'DNA (8)', 'E-cadherin', 'Vimentin', 'CDX-2',
       'DNA (9)', 'Lamin-A/B/C', 'Desmin', 'CD31', 'DNA (10)', 'PCNA',
       'Collagen']

# Sort feature columns alphabetically
sorted_feature_columns = sorted(feature_columns)

# Get the mapping from old to new indices
old_to_new = {feature: i for i, feature in enumerate(feature_columns)}
new_to_old = {i: old_to_new[feature] for i, feature in enumerate(sorted_feature_columns)}

# Reorder shap_values_array using the mapping
reordered_shap_values = shap_values_array[:, [new_to_old[i] for i in range(len(feature_columns))], :]

# Update feature_columns to be sorted
feature_columns = sorted_feature_columns

# %%
reordered_shap_values.shape
# Out:
# (933253, 31, 2)

# %%
feature_columns = ['DNA', 'DNA (2)', 'DNA (3)', 'CD3', 'CD45RO', 'DNA (4)',
       'Pan-cytokeratin', 'Aortic smooth muscle actin', 'DNA (5)', 'CD4',
       'CD45', 'PD-1', 'DNA (6)', 'CD20', 'CD68', 'CD8a', 'DNA (7)', 'CD163',
       'FOXP3', 'PD-L1', 'DNA (8)', 'E-cadherin', 'Vimentin', 'CDX-2',
       'DNA (9)', 'Lamin-A/B/C', 'Desmin', 'CD31', 'DNA (10)', 'PCNA',
       'Collagen']

sorted_feature_columns = sorted(feature_columns)
cluster_7 = csv_df[csv_df['kmeans'] == 7].index.tolist()
cluster_7_vals = reordered_shap_values[cluster_7].sum(axis=2)
mean_cluster_7_vals = cluster_7_vals.mean(axis=0)
# bar plot of mean_cluster_7_vals, which have labels as feature_columns
plt.bar(sorted_feature_columns, mean_cluster_7_vals)
plt.xticks(rotation=90)
plt.show()

# %%
.shape
# Out:
# (78091, 31)

# %%
np.save(f"/Users/swarchol/Research/seal/data/gregg.shap.npy", reordered_shap_values)
