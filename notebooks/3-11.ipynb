# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/swarchol/Desktop/VAE OUTPUT/LSP26239_001_JRL_melanoma_test1_001360--unmicst_nucleiRing.csv')

# %%
df
# Out:
#           CellID         DNA1           AF1         CD31         Ki67  \
# 0              1  2837.820513   1531.347985   528.194139   767.809524
# 1              2  3080.688312   1372.448052   470.818182   806.383117
# 2              3  2810.190114   1439.376426   490.148289   786.197719
# 3              4  3340.231317   1736.811388   592.295374   970.583630
# 4              5  5382.196581   3448.166667   664.688034  1092.465812
# ...          ...          ...           ...          ...          ...
# 1031774  1031775  3185.413592    661.017476   392.664078   461.792233
# 1031775  1031776  4038.283019    956.150943  1204.647799   535.345912
# 1031776  1031777  2685.469194   9671.052133    34.080569     7.071090
# 1031777  1031778  2801.008889  10966.760000    13.711111     0.488889
# 1031778  1031779  2681.357326  10505.611825    68.095116     9.768638
#
#                CD68        CD163         CD20         CD4        CD8a  ...  \
# ...

# %%
embedding = pd.read_csv('/Users/swarchol/Downloads/vae_results.csv')

# %%
embedding
# Out:
#        Unnamed: 0  X_centroid  Y_centroid       SOX10         ECAD  \
# 0               0        6598       16892  325.473902  1243.211268
# 1               1       39667       11351  304.105048  1249.608458
# 2               2       48323       31591  364.294239  2248.753086
# 3               3       28861       32918  343.903023  1618.380353
# 4               4       57151        5776  251.146853   710.028971
# ...           ...         ...         ...         ...          ...
# 99995       99995       19539       35443  337.194882  2030.259843
# 99996       99996        9375       23800  320.472093  1434.060465
# 99997       99997       26352       20257  273.242466  1653.198630
# 99998       99998       23296       11275  257.516842   987.104211
# 99999       99999       16067       35997  270.587996   748.063072
#
#              CD45        CD3e        CD68         pH3        Ki67  ...  \
# 0      250.910522  230.719138  230.723281  269.525269  730.714167  ...
# ...

# %%
# # embedding
# does any column look like CellId
# CellId
for c in embedding.columns:
    if 'CellId' in c:
        print(c)
        break
# drop column 'Unnamed: 0',
embedding.shape
# Out:
# (100000, 139)

# %%
embedding.columns
# drop column 'Unnamed: 0',
try:
    embedding = embedding.drop(columns=['Unnamed: 0'])
except:
    pass
for c in embedding.columns:
    print(c)
# Out:
# X_centroid
# Y_centroid
# SOX10
# ECAD
# CD45
# CD3e
# CD68
# pH3
# Ki67
# UMAP1
# UMAP2
# z0
# z1
# z2
# z3
# z4
# z5
# z6
# z7
# z8
# z9
# z10
# z11
# z12
# z13
# z14
# z15
# z16
# z17
# z18
# z19
# z20
# z21
# z22
# z23
# z24
# z25
# z26
# z27
# z28
# z29
# z30
# z31
# z32
# z33
# z34
# z35
# z36
# z37
# z38
# z39
# z40
# z41
# z42
# z43
# z44
# z45
# z46
# z47
# z48
# z49
# z50
# z51
# z52
# z53
# z54
# z55
# z56
# z57
# z58
# z59
# z60
# z61
# z62
# z63
# z64
# z65
# z66
# z67
# z68
# z69
# z70
# z71
# z72
# z73
# z74
# z75
# z76
# z77
# z78
# z79
# z80
# z81
# z82
# z83
# z84
# z85
# z86
# z87
# z88
# z89
# z90
# z91
# z92
# z93
# z94
# z95
# z96
# z97
# z98
# z99
# z100
# z101
# z102
# z103
# z104
# z105
# z106
# z107
# z108
# z109
# z110
# z111
# z112
# z113
# z114
# z115
# z116
# z117
# z118
# z119
# z120
# z121
# z122
# z123
# z124
# z125
# z126
# z127

# %%
import matplotlib.pyplot as plt

plt.scatter(embedding['UMAP1'], embedding['UMAP1'], alpha=0.01)
plt.show()
